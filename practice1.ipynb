# %%
import numpy as np
marks=[12,34,15,34]

student_marks= np.array(marks)
print(student_marks)
print(type(student_marks))
print(type(marks))
print(student_marks+5)
# Out:
# [12 34 15 34]
# <class 'numpy.ndarray'>
# <class 'list'>
# [17 39 20 39]

# %%
 # !gdown 1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# To: /content/survey.txt
# 100% 2.55k/2.55k [00:00<00:00, 10.1MB/s]

# %%
score=np.loadtxt('survey.txt',dtype=int)
len(score)
# Out:
# 1167

# %%
score>=9 #output is a list containing boolean values
p=sum(score>=9)
print(p)
# Out:
# 609

# %%
score<=6 #output is a list containing boolean values
q=sum(score<=6)
print(q)
# Out:
# 332

# %%
nps=(p-q)*100/len(score)
print(nps)
# Out:
# 23.736075407026565

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_"
# Out:
# --2026-03-01 15:55:57--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 173.194.203.113, 173.194.203.100, 173.194.203.101, ...
# Connecting to drive.google.com (drive.google.com)|173.194.203.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2026-03-01 15:55:57--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.135.132, 2607:f8b0:400e:c01::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.135.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_’
# ...

# %%
df=pd.read_csv('/content/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail(50)
# Out:
#                  country  year  population continent  life_exp      gdp_cap
# 1654             Vietnam  2002    80908147      Asia    73.017  1764.456677
# 1655             Vietnam  2007    85262356      Asia    74.249  2441.576404
# 1656  West Bank and Gaza  1952     1030585      Asia    43.160  1515.592329
# 1657  West Bank and Gaza  1957     1070439      Asia    45.671  1827.067742
# 1658  West Bank and Gaza  1962     1133134      Asia    48.127  2198.956312
# 1659  West Bank and Gaza  1967     1142636      Asia    51.631  2649.715007
# 1660  West Bank and Gaza  1972     1089572      Asia    56.532  3133.409277
# 1661  West Bank and Gaza  1977     1261091      Asia    60.765  3682.831494
# 1662  West Bank and Gaza  1982     1425876      Asia    64.406  4336.032082
# 1663  West Bank and Gaza  1987     1691210      Asia    67.046  5107.197384
# 1664  West Bank and Gaza  1992     2104779      Asia    69.718  6017.654756
# ...

# %%
print(df['life_exp'].min())
print(df['life_exp'].max())
# Out:
# 23.599
# 82.603

# %%
comp=df['life_exp']==23.599
print(comp)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: life_exp, Length: 1704, dtype: bool

# %%
df[comp]
# Out:
#      country  year  population continent  life_exp     gdp_cap
# 1292  Rwanda  1992     7290203    Africa    23.599  737.068595

# %%
comp=df['life_exp']==df['life_exp'].max()
print(comp)
df[comp]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: life_exp, Length: 1704, dtype: bool
#     country  year  population continent  life_exp      gdp_cap
# 803   Japan  2007   127467972      Asia    82.603  31656.06806

# %%
df_com=df[df['country']=='India']
df_com
#df_com.plot('year','gdp_cap')
# Out:
#     country  year  population continent  life_exp      gdp_cap
# 696   India  1952   372000000      Asia    37.373   546.565749
# 697   India  1957   409000000      Asia    40.249   590.061996
# 698   India  1962   454000000      Asia    43.605   658.347151
# 699   India  1967   506000000      Asia    47.193   700.770611
# 700   India  1972   567000000      Asia    50.651   724.032527
# 701   India  1977   634000000      Asia    54.208   813.337323
# 702   India  1982   708000000      Asia    56.596   855.723538
# 703   India  1987   788000000      Asia    58.553   976.512676
# 704   India  1992   872000000      Asia    60.223  1164.406809
# 705   India  1997   959000000      Asia    61.765  1458.817442
# 706   India  2002  1034172547      Asia    62.879  1746.769454
# 707   India  2007  1110396331      Asia    64.698  2452.210407

# %%
df_com.plot('year','gdp_cap')
# Out:
# <Axes: xlabel='year'>

# %%
add=sum(df['gdp_cap'])
print(add)
# Out:
# 12294917.3463855

# %%
avg=add/len(df)
print(avg)
# Out:
# 7215.327081212147
